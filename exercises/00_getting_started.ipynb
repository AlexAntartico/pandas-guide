# %% [markdown]
# # 00 — Getting Started with pandas
#
# Maps to **MODULE-00**. You will create `Series`/`DataFrame` objects from scratch, then load and inspect a real table.
#
# Data: `datasets/raw/customers.csv`  •  Docs: `datasets/README.md`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Create a Series from scratch
#
# A `Series` is a 1-D labeled array (a single spreadsheet column).

# %%
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
s

# %%
# Access by label vs by position
s['a']        # label-based
s.iloc[0]     # position-based

# %% [markdown]
# ### 2. Create a DataFrame from a dict

# %%
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'salary': [50000, 60000, 70000],
})
df

# %% [markdown]
# ### 3. Load a real table and inspect its structure

# %%
customers = pd.read_csv('datasets/raw/customers.csv')
customers.shape

# %%
customers.columns.tolist()

# %%
customers.dtypes

# %%
customers.info()   # memory usage + non-null counts

# %%
# Set a column as the index (faster lookups, meaningful labels)
customers_indexed = customers.set_index('customer_id')
customers_indexed.head()

# %% [markdown]
# ### 4. View the data

# %%
customers.head(5)                    # first rows
customers.tail(3)                    # last rows
customers.sample(5, random_state=42)  # random rows
